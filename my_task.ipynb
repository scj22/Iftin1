# %% [markdown]
# <a href="https://colab.research.google.com/github/Iftin1/Iftin1/blob/main/my_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv("student_cleaning_practice_200_v2.csv")

df.head()
# Out:
#   student_id           name   age  gender        school       city  \
# 0     STU034   Abdi Mohamed  19.0    Male  Bile Academy     Baidoa
# 1     STU086    Yusuf Yusuf  22.0    Male  Hodan School    Kismayo
# 2     STU057   Yusuf Hassan  18.0  Female  Hamar School     Baidoa
# 3     STU105    Hodan Yusuf  20.0     NaN  Bile Academy     Garowe
# 4     STU121  Ifrah Warsame  17.0    Male  Hamar School  Mogadishu
#
#    study_hours_per_day  attendance_percent internet_access parent_support  \
# 0                    4                87.0              No             No
# 1                    5                87.0              No             No
# 2                    2                95.0              No             No
# 3                    5                84.0              No            Yes
# 4                    3                70.0             Yes            Yes
#
#    absences  exam_score grade
# 0         3        69.0     C
# 1         0        98.0     A
# ...

# %% [markdown]
# The `student_cleaning_practice_200_v2.csv` file has already been loaded into a DataFrame named `df` in the previous cell (`vkcRoa-1144G`). Let's display the head to confirm:

# %%
display(df.head())
# Out:
#   student_id           name   age  gender        school       city  \
# 0     STU034   Abdi Mohamed  19.0    Male  Bile Academy     Baidoa
# 1     STU086    Yusuf Yusuf  22.0    Male  Hodan School    Kismayo
# 2     STU057   Yusuf Hassan  18.0  Female  Hamar School     Baidoa
# 3     STU105    Hodan Yusuf  20.0     NaN  Bile Academy     Garowe
# 4     STU121  Ifrah Warsame  17.0    Male  Hamar School  Mogadishu
#
#    study_hours_per_day  attendance_percent internet_access parent_support  \
# 0                    4                87.0              No             No
# 1                    5                87.0              No             No
# 2                    2                95.0              No             No
# 3                    5                84.0              No            Yes
# 4                    3                70.0             Yes            Yes
#
#    absences  exam_score grade
# 0         3        69.0     C
# 1         0        98.0     A
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   student_id           200 non-null    object
#  1   name                 200 non-null    object
#  2   age                  188 non-null    float64
#  3   gender               190 non-null    object
#  4   school               200 non-null    object
#  5   city                 192 non-null    object
#  6   study_hours_per_day  200 non-null    int64
#  7   attendance_percent   189 non-null    float64
#  8   internet_access      200 non-null    object
#  9   parent_support       200 non-null    object
#  10  absences             200 non-null    int64
#  11  exam_score           192 non-null    float64
#  12  grade                200 non-null    object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 20.4+ KB

# %%
df.isnull().sum()

df.isna().sum()
# Out:
# student_id              0
# name                    0
# age                    12
# gender                 10
# school                  0
# city                    8
# study_hours_per_day     0
# attendance_percent     11
# internet_access         0
# parent_support          0
# absences                0
# exam_score              8
# grade                   0
# dtype: int64

# %%
df["age"]=df["age"].fillna(df["age"].median())

# %%
df.isnull().sum()

df.isna().sum()
# Out:
# student_id              0
# name                    0
# age                     0
# gender                 10
# school                  0
# city                    8
# study_hours_per_day     0
# attendance_percent     11
# internet_access         0
# parent_support          0
# absences                0
# exam_score              8
# grade                   0
# dtype: int64

# %%
df["gender"]=df["gender"].fillna(df["gender"].mode()[0])

# %%
df.isnull().sum()

df.isna().sum()
# Out:
# student_id              0
# name                    0
# age                     0
# gender                  0
# school                  0
# city                    8
# study_hours_per_day     0
# attendance_percent     11
# internet_access         0
# parent_support          0
# absences                0
# exam_score              8
# grade                   0
# dtype: int64

# %%
df["attendance_percent"]=df["attendance_percent"].fillna(df["attendance_percent"].median())

# %%
df.isnull().sum()

df.isna().sum()
# Out:
# student_id             0
# name                   0
# age                    0
# gender                 0
# school                 0
# city                   8
# study_hours_per_day    0
# attendance_percent     0
# internet_access        0
# parent_support         0
# absences               0
# exam_score             8
# grade                  0
# dtype: int64

# %%
df["city"]=df["city"].fillna(df["city"].mode()[0])

# %%
df.isnull().sum()

df.isna().sum()
# Out:
# student_id             0
# name                   0
# age                    0
# gender                 0
# school                 0
# city                   0
# study_hours_per_day    0
# attendance_percent     0
# internet_access        0
# parent_support         0
# absences               0
# exam_score             8
# grade                  0
# dtype: int64

# %%
df["exam_score"]=df["exam_score"].fillna(df["exam_score"].median())

# %%
df.isnull().sum()

df.isna().sum()
# Out:
# student_id             0
# name                   0
# age                    0
# gender                 0
# school                 0
# city                   0
# study_hours_per_day    0
# attendance_percent     0
# internet_access        0
# parent_support         0
# absences               0
# exam_score             0
# grade                  0
# dtype: int64

# %%
df[df.duplicated(keep="first")]
# Out:
#     student_id          name   age  gender          school       city  \
# 44      STU057  Yusuf Hassan  18.0  Female    Hamar School     Baidoa
# 75      STU038   Yusuf Yusuf  20.0  Female    Hamar School    Kismayo
# 97      STU067  Ibrahim Abdi  21.0    Male    Hodan School   Hargeisa
# 105     STU012   Hodan Ahmed  18.0    Male  Banadir School   Hargeisa
# 107     STU081      Ali Omar  21.0  Female    Hamar School     Baidoa
# 113     STU190    Leyla Omar  18.0  Female    Hodan School     Baidoa
# 125     STU145   Sahra Yusuf  20.0  Female    Hodan School  Mogadishu
# 146     STU142  Fadumo Ahmed  22.0  Female    Hodan School    Kismayo
# 149     STU005  Yusuf Hassan  15.0    Male  Banadir School  Mogadishu
# 162     STU106    Ifrah Abdi  16.0  Female  Banadir School  Mogadishu
#
#      study_hours_per_day  attendance_percent internet_access parent_support  \
# 44                     2                95.0              No             No
# ...

# %%
df=df.drop_duplicates()

# %%
df[df.duplicated(keep="first")]
# Out:
# Empty DataFrame
# Columns: [student_id, name, age, gender, school, city, study_hours_per_day, attendance_percent, internet_access, parent_support, absences, exam_score, grade]
# Index: []

# %%
df.head()
# Out:
#   student_id           name   age  gender        school       city  \
# 0     STU034   Abdi Mohamed  19.0    Male  Bile Academy     Baidoa
# 1     STU086    Yusuf Yusuf  22.0    Male  Hodan School    Kismayo
# 2     STU057   Yusuf Hassan  18.0  Female  Hamar School     Baidoa
# 3     STU105    Hodan Yusuf  20.0  Female  Bile Academy     Garowe
# 4     STU121  Ifrah Warsame  17.0    Male  Hamar School  Mogadishu
#
#    study_hours_per_day  attendance_percent internet_access parent_support  \
# 0                    4                87.0              No             No
# 1                    5                87.0              No             No
# 2                    2                95.0              No             No
# 3                    5                84.0              No            Yes
# 4                    3                70.0             Yes            Yes
#
#    absences  exam_score grade
# 0         3        69.0     C
# 1         0        98.0     A
# ...

# %%
df["gender"].value_counts()
# Out:
# gender
# Female      104
# Male         81
# female        3
#  Male         1
#  Female       1
# Name: count, dtype: int64

# %%
percent = (df["gender"].value_counts(normalize=True) * 100).round(0).astype(int)

# %%
df["gender"].value_counts()
# Out:
# gender
# Female      104
# Male         81
# female        3
#  Male         1
#  Female       1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'study_hours_per_day'}>],
#        [<Axes: title={'center': 'attendance_percent'}>,
#         <Axes: title={'center': 'absences'}>],
#        [<Axes: title={'center': 'exam_score'}>, <Axes: >]], dtype=object)

# %%
df.plot(kind="box")
# Out:
# <Axes: >

# %%
df.to_csv("cleaned_student_data.csv",index=False)

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'student_cleaning_practice_200_v2.csv',
#  'cleaned_student_data.csv',
#  'sample_data']
